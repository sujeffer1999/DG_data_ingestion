# %% [markdown]
# #### Creating utility file

# %%
# %%writefile testutility.py
import logging
import os
import subprocess
import yaml
import pandas as pd
import datetime
import gc
import re


################
# File Reading #
################

def read_config_file(filepath):
    with open(filepath, 'r') as stream:
        try:
            return yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            logging.error(exc)


def replacer(string, char):
    pattern = char + '{2,}'
    string = re.sub(pattern, char, string)
    return string


def col_header_val(df, table_config):
    """ replace whitespaces in the column  and standardized column names """
    df.columns = df.columns.str.lower()
    df.columns = df.columns.str.replace('[^\w]', '_', regex=True)
    df.columns = list(map(lambda x: x.strip('_'), list(df.columns)))
    df.columns = list(map(lambda x: replacer(x, '_'), list(df.columns)))
    expected_col = list(map(lambda x: x.lower(), table_config['columns']))
    expected_col.sort()
    df.columns = list(map(lambda x: x.lower(), list(df.columns)))
    df = df.reindex(sorted(df.columns), axis=1)
    if len(df.columns) == len(expected_col) and list(expected_col) == list(df.columns):
        print("column name and column length validation passed")
        return 1
    else:
        print("column name and column length validation failed")
        mismatched_columns_file = list(set(df.columns).difference(expected_col))
        print("Following File columns are not in the YAML file", mismatched_columns_file)
        missing_YAML_file = list(set(expected_col).difference(df.columns))
        print("Following YAML columns are not in the file uploaded", missing_YAML_file)
        logging.info(f'df columns: {df.columns}')
        logging.info(f'expected columns: {expected_col}')
        return 0
# Out:
# Writing testutility.py

# %% [markdown]
# #### Creating yaml file

# %%
# %%writefile file.yaml
# file_type: csv
# dataset_name: testfile
# file_name: postcovid_reviews
# table_name: edsurv
# inbound_delimeter: ","
# outbound_delimeter: "|"
# skip_leading_rows: 1
# columns:
#     -business_id
#     -name
#     -address
#     -state_
#     -city
#     -postal_code
#     -latitude
#     -longitude
#     -stars
#     -review_count
#     -is_open
#     -categories
#     -hours
#     -review_id
#     -user_id
#     -customer_stars
#     -useful
#     -funny
#     -cool
#     -text_
#     -date_
# Out:
# Overwriting file.yaml

# %% [markdown]
# #### Reading data with pandas

# %%
import pandas as pd
df=pd.read_csv("data/postcovid_reviews.csv")
df.head()
# Out:
#               business_id                              name  \
# 0  2WRCcQATOe_Em0k61T6kvQ  Yook Korean Grilled BBQ & Bistro
# 1  oug5bLTWP_YTtj1C3_X6Xw          Gourdough's Public House
# 2  imUlMANF0tNDxWOXdxfP9w             Donut Express & Cakes
# 3  mP1EdIafQKMuOm9O4PzAfA      Barcelona Wine Bar South End
# 4  4UjU7F_EX3lgUtkzN8Bbrw                     Shan-A-Punjab
#
#                address state_       city postal_code   latitude   longitude  \
# 0  2408 Nanaimo Street     BC  Vancouver     V5N 5E4  49.262732 -123.056371
# 1    2700 S Lamar Blvd     TX     Austin       78704  30.245382  -97.780437
# 2          258 Main St     MA   Medfield       02052  42.193721  -71.290251
# 3       525 Tremont St     MA     Boston       02116  42.344936  -71.070544
# 4       500 Harvard St     MA  Brookline       02446  42.348017  -71.129557
#
#    stars  review_count  ...  \
# 0    4.0            74  ...
# 1    4.0          1534  ...
# 2    5.0            42  ...
# 3    4.5          1097  ...
# 4    4.0           426  ...
#
#                                           categories  \
# 0                      Restaurants, Barbeque, Korean
# 1  Karaoke, Pubs, Comfort Food, Bars, Gastropubs,...
# 2  Food, Bakeries, Custom Cakes, Donuts, Restaurants
# 3  Spanish, Bars, Tapas Bars, Wine Bars, Tapas/Sm...
# 4  Nightlife, Indian, Vegetarian, Cocktail Bars, ...
#
#                                                hours               review_id  \
# 0  {'Monday': '0:0-0:0', 'Wednesday': '11:30-22:0...  t2I2CLHd7MpULwwqjPv0vA
# 1  {'Monday': '0:0-0:0', 'Tuesday': '11:0-0:0', '...  gcJK-cQHFrrP1wnRUsQ9Jw
# 2  {'Monday': '5:0-13:0', 'Tuesday': '5:0-13:0', ...  wvtTSr4GGGnNhfnj7K1R6g
# 3  {'Monday': '12:0-21:0', 'Tuesday': '12:0-21:0'...  twUhcgH6ODfMv7ZXEQMX6A
# 4  {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...  vPFrlWYmxdUxjXS2JQquHQ
#
#                   user_id customer_stars  useful  funny  cool  \
# 0  iBRhL3g62aQzZ7nrJc-KCg              1       0      0     0
# 1  qcpg7m7V-5XgHZzdk_f_hQ              4       1      0     0
# 2  os_bbAergdkI_OiYyLrlrg              2       0      0     0
# 3  clEAaBNgrnS7PofAonfkJA              4       1      0     0
# 4  evqTtztHLyPSy3n0KcrJYg              1       1      0     1
#
#                                                text_                date_
# 0  Decent food horrible service. I would give thi...  2020-02-15 21:09:17
# 1  I've been wanting to try Gourdough's for a whi...  2020-09-30 01:17:12
# 2  The last custom cake bought in October 2020 wa...  2020-12-24 18:11:13
# 3  I came here with a group of 4 on a Saturday ni...  2020-02-19 00:23:46
# 4  Ate the lunch buffet at Shan-a-Punjab many tim...  2020-01-30 23:23:16
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['business_id', 'name', 'address', 'state_', 'city', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'categories', 'hours', 'review_id', 'user_id', 'customer_stars',
#        'useful', 'funny', 'cool', 'text_', 'date_'],
#       dtype='object')

# %% [markdown]
# #### Reading config file

# %%
import testutility as util
df_config= util.read_config_file("file.yaml")
df_config
# Out:
# {'file_type': 'csv',
#  'dataset_name': 'testfile',
#  'file_name': 'postcovid_reviews',
#  'table_name': 'edsurv',
#  'inbound_delimeter': ',',
#  'outbound_delimeter': '|',
#  'skip_leading_rows': 1,
#  'columns': '-business_id -name -address -state_ -city -postal_code -latitude -longitude -stars -review_count -is_open -categories -hours -review_id -user_id -customer_stars -useful -funny -cool -text_ -date_'}

# %%
import pandas as pd 
file_type=df_config['file_type']
source_file="data/"+  df_config['file_name'] + f'.{file_type}'

print(source_file)

df2=pd.read_csv(source_file,df_config['inbound_delimeter'])
print("New dataset:", df2)
# Out:
# data/postcovid_reviews.csv
# New dataset:                    business_id                              name  \
# 0       2WRCcQATOe_Em0k61T6kvQ  Yook Korean Grilled BBQ & Bistro
# 1       oug5bLTWP_YTtj1C3_X6Xw          Gourdough's Public House
# 2       imUlMANF0tNDxWOXdxfP9w             Donut Express & Cakes
# 3       mP1EdIafQKMuOm9O4PzAfA      Barcelona Wine Bar South End
# 4       4UjU7F_EX3lgUtkzN8Bbrw                     Shan-A-Punjab
# ...                        ...                               ...
# 400290  Q78fYV6B6P6GmX07YVgi4g             Maudie’s Hill Country
# 400291  RmRAhZC0FcxlwW0nEZv1GQ        Texican Cafe - South Lamar
# 400292  P5x-GukFEq4UeSOl6GJfAw    Bubbalou's Bodacious Bar B Que
# 400293  cgNDiWCaSlqqxx1A6r65bA                        Hop N Cork
# 400294  dmkDZKPsK8lmwFuLiFQ0Zw                       Planted PDX
#
#                             address state_         city postal_code  \
# 0               2408 Nanaimo Street     BC    Vancouver     V5N 5E4
# 1                 2700 S Lamar Blvd     TX       Austin       78704
# 2                       258 Main St     MA     Medfield       02052
# 3                    525 Tremont St     MA       Boston       02116
# 4                    500 Harvard St     MA    Brookline       02446
# ...                             ...    ...          ...         ...
# 400290             12506 Shops Pkwy     TX     Bee Cave       78738
# 400291    4141 Capital Of Texas Hwy     TX       Austin       78704
# 400292    5818 Conroy Windermere Rd     FL      Orlando       32835
# 400293  17450 Lower Boones Ferry Rd     OR  Lake Oswego       97035
# 400294       4390 SW Garden Home Rd     OR     Portland       97219
#
#          latitude   longitude  stars  review_count  ...  \
# 0       49.262732 -123.056371    4.0            74  ...
# 1       30.245382  -97.780437    4.0          1534  ...
# 2       42.193721  -71.290251    5.0            42  ...
# 3       42.344936  -71.070544    4.5          1097  ...
# 4       42.348017  -71.129557    4.0           426  ...
# ...           ...         ...    ...           ...  ...
# 400290  30.304761  -97.937394    3.0           310  ...
# 400291  30.236379  -97.796809    3.5           233  ...
# 400292  28.493782  -81.460856    4.0           370  ...
# 400293  45.399154 -122.737600    4.0           137  ...
# 400294  45.465756 -122.721888    4.5            24  ...
#
#                                                categories  \
# 0                           Restaurants, Barbeque, Korean
# 1       Karaoke, Pubs, Comfort Food, Bars, Gastropubs,...
# 2       Food, Bakeries, Custom Cakes, Donuts, Restaurants
# 3       Spanish, Bars, Tapas Bars, Wine Bars, Tapas/Sm...
# 4       Nightlife, Indian, Vegetarian, Cocktail Bars, ...
# ...                                                   ...
# 400290     Mexican, Bars, Nightlife, Tex-Mex, Restaurants
# 400291             Seafood, Mexican, Restaurants, Tex-Mex
# 400292  Caterers, Barbeque, Restaurants, Event Plannin...
# 400293  Nightlife, Wine Bars, Beer Bar, Bars, Restaura...
# 400294              Food Trucks, Restaurants, Food, Vegan
#
#                                                     hours  \
# 0       {'Monday': '0:0-0:0', 'Wednesday': '11:30-22:0...
# 1       {'Monday': '0:0-0:0', 'Tuesday': '11:0-0:0', '...
# 2       {'Monday': '5:0-13:0', 'Tuesday': '5:0-13:0', ...
# 3       {'Monday': '12:0-21:0', 'Tuesday': '12:0-21:0'...
# 4       {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# ...                                                   ...
# 400290  {'Monday': '0:0-0:0', 'Tuesday': '9:0-21:0', '...
# 400291  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 400292  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 400293  {'Monday': '0:0-0:0', 'Tuesday': '16:0-20:0', ...
# 400294  {'Tuesday': '11:0-19:30', 'Wednesday': '11:0-1...
#
#                      review_id                 user_id customer_stars  useful  \
# 0       t2I2CLHd7MpULwwqjPv0vA  iBRhL3g62aQzZ7nrJc-KCg              1       0
# 1       gcJK-cQHFrrP1wnRUsQ9Jw  qcpg7m7V-5XgHZzdk_f_hQ              4       1
# 2       wvtTSr4GGGnNhfnj7K1R6g  os_bbAergdkI_OiYyLrlrg              2       0
# 3       twUhcgH6ODfMv7ZXEQMX6A  clEAaBNgrnS7PofAonfkJA              4       1
# 4       vPFrlWYmxdUxjXS2JQquHQ  evqTtztHLyPSy3n0KcrJYg              1       1
# ...                        ...                     ...            ...     ...
# 400290  BFFoylBvbNv4ZubKjKqdXQ  TLGJNTc0vzW4s5-ym2RZxQ              2       0
# 400291  A_bdec6c70w_nH4ZqUu_UQ  ysUk0irSYQ-kZgAZoD5uSw              2       0
# 400292  e12Lu1xDP64sY7QICpAW9A  8chvqYiv0C27kJmAT_I4CA              4       1
# 400293  Kc9bVQvMwUjehqhPkDBEvQ  wbhaPKJIYryGrCBVWJ7Nmg              5       0
# 400294  FfhmA0G0zrRjHskp-7O8UQ  IlxM3NGJOtNXPz5cupqNDQ              5       0
#
#         funny  cool                                              text_  \
# 0           0     0  Decent food horrible service. I would give thi...
# 1           0     0  I've been wanting to try Gourdough's for a whi...
# 2           0     0  The last custom cake bought in October 2020 wa...
# 3           0     0  I came here with a group of 4 on a Saturday ni...
# 4           0     1  Ate the lunch buffet at Shan-a-Punjab many tim...
# ...       ...   ...                                                ...
# 400290      0     0  Make sure you don't order nachos here! I get i...
# 400291      0     0  We have been going to Texican for years and si...
# 400292      0     0  I placed a carry-out order for my family, and ...
# 400293      0     0  Please support this place! They are trying to ...
# 400294      0     0  Yes please! We had the Arepas falafel style an...
#
#                       date_
# 0       2020-02-15 21:09:17
# 1       2020-09-30 01:17:12
# 2       2020-12-24 18:11:13
# 3       2020-02-19 00:23:46
# 4       2020-01-30 23:23:16
# ...                     ...
# 400290  2020-11-24 16:08:26
# 400291  2020-11-29 16:27:22
# 400292  2020-06-15 22:56:46
# 400293  2021-01-17 02:04:29
# 400294  2021-01-25 14:53:13
#
# [400295 rows x 21 columns]

# %% [markdown]
# #### Validate the header of file

# %%
util.col_header_val(df2,df_config)
# Out:
# column name and column length validation failed
# Following File columns are not in the YAML file ['longitude', 'address', 'funny', 'business_id', 'postal_code', 'review_id', 'latitude', 'state', 'user_id', 'customer_stars', 'categories', 'review_count', 'is_open', 'date', 'stars', 'useful', 'city', 'cool', 'text', 'name', 'hours']
# Following YAML columns are not in the file uploaded ['n', 'i', 'a', 't', 'w', 'm', '_', 'd', 'l', 'u', 'p', 's', 'b', 'f', 'v', 'c', 'r', 'g', ' ', 'x', '-', 'y', 'o', 'e', 'h']
# 0

# %%
if util.col_header_val(df2,config_data)==0:
    print("validation failed")
else:
    print("col validation passed")
# Out:
# column name and column length validation failed
# Following File columns are not in the YAML file ['longitude', 'address', 'funny', 'business_id', 'postal_code', 'review_id', 'latitude', 'state', 'user_id', 'customer_stars', 'categories', 'review_count', 'is_open', 'date', 'stars', 'useful', 'city', 'cool', 'text', 'name', 'hours']
# Following YAML columns are not in the file uploaded ['n', 'i', 'a', 't', 'w', 'm', '_', 'd', 'l', 'u', 'p', 's', 'b', 'f', 'v', 'c', 'r', 'g', ' ', 'x', '-', 'y', 'o', 'e', 'h']
# validation failed

# %% [markdown]
# ### Summary
# <p>
#     Total number of rows: 400294 <br>
#     Total number of columns: 21 <br>
#     File size: 2+ GB
# <p>
